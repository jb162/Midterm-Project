# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
movies_df = pd.read_csv('MoviesOnStreamingPlatforms.csv')
movies_df=movies_df.iloc[:, 1:].set_index('ID')
movies_df.head()
# Out:
#                                        Title  Year  Age Rotten Tomatoes  \
# ID
# 1                               The Irishman  2019  18+          98/100
# 2                                     Dangal  2016   7+          97/100
# 3   David Attenborough: A Life on Our Planet  2020   7+          95/100
# 4          Lagaan: Once Upon a Time in India  2001   7+          94/100
# 5                                       Roma  2018  18+          94/100
#
#     Netflix  Hulu  Prime Video  Disney+  Type
# ID
# 1         1     0            0        0     0
# 2         1     0            0        0     0
# 3         1     0            0        0     0
# 4         1     0            0        0     0
# 5         1     0            0        0     0

# %%
# Iterate through each row
#   if Netflix == 1 then platform = 'Netflix'

movies_df['Streaming platform']=''
for each_platform in ['Netflix', 'Hulu', 'Prime Video', 'Disney+']: 
    movies_df.loc[movies_df[each_platform]==1, 'Streaming platform']=each_platform

# %%
Highest_number_of_movies=movies_df['Streaming platform'].value_counts()
# Out:
# Prime Video    4100
# Netflix        3550
# Hulu            943
# Disney+         922
# Name: Streaming platform, dtype: int64

# %% [markdown]
# #### Next we look for the Streaming platform that provides the highest number of critically acclaimed movies.

# %%
#Split Rotten Tomatoes column in to two different cells.
data=movies_df['Rotten Tomatoes'].str.split('/', expand=True)

# %%
#Add the split value into a new column called rating and convert the values to float.
movies_df['Rating']=pd.to_numeric(data[0])
movies_df
# Out:
#                                          Title  Year  Age Rotten Tomatoes  \
# ID
# 1                                 The Irishman  2019  18+          98/100
# 2                                       Dangal  2016   7+          97/100
# 3     David Attenborough: A Life on Our Planet  2020   7+          95/100
# 4            Lagaan: Once Upon a Time in India  2001   7+          94/100
# 5                                         Roma  2018  18+          94/100
# ...                                        ...   ...  ...             ...
# 9511                        Most Wanted Sharks  2020  NaN          14/100
# 9512             Doc McStuffins: The Doc Is In  2020  NaN          13/100
# 9513                     Ultimate Viking Sword  2019  NaN          13/100
# 9514           Hunt for the Abominable Snowman  2011  NaN          10/100
# 9515       Women of Impact: Changing the World  2019   7+          10/100
#
#       Netflix  Hulu  Prime Video  Disney+  Type Streaming platform  Rating
# ID
# 1           1     0            0        0     0            Netflix    98.0
# 2           1     0            0        0     0            Netflix    97.0
# 3           1     0            0        0     0            Netflix    95.0
# 4           1     0            0        0     0            Netflix    94.0
# 5           1     0            0        0     0            Netflix    94.0
# ...       ...   ...          ...      ...   ...                ...     ...
# 9511        0     0            0        1     0            Disney+    14.0
# 9512        0     0            0        1     0            Disney+    13.0
# 9513        0     0            0        1     0            Disney+    13.0
# 9514        0     0            0        1     0            Disney+    10.0
# 9515        0     0            0        1     0            Disney+    10.0
#
# [9515 rows x 11 columns]

# %%
#Clean data set by dropping uneccessary rows.
clean_movies_df=movies_df.drop(columns=['Netflix', 'Hulu', 'Prime Video', 'Disney+','Rotten Tomatoes', 'Type'])
clean_movies_df
# Out:
#                                          Title  Year  Age Streaming platform  \
# ID
# 1                                 The Irishman  2019  18+            Netflix
# 2                                       Dangal  2016   7+            Netflix
# 3     David Attenborough: A Life on Our Planet  2020   7+            Netflix
# 4            Lagaan: Once Upon a Time in India  2001   7+            Netflix
# 5                                         Roma  2018  18+            Netflix
# ...                                        ...   ...  ...                ...
# 9511                        Most Wanted Sharks  2020  NaN            Disney+
# 9512             Doc McStuffins: The Doc Is In  2020  NaN            Disney+
# 9513                     Ultimate Viking Sword  2019  NaN            Disney+
# 9514           Hunt for the Abominable Snowman  2011  NaN            Disney+
# 9515       Women of Impact: Changing the World  2019   7+            Disney+
#
#       Rating
# ID
# 1       98.0
# 2       97.0
# 3       95.0
# 4       94.0
# 5       94.0
# ...      ...
# 9511    14.0
# 9512    13.0
# 9513    13.0
# 9514    10.0
# 9515    10.0
#
# [9515 rows x 5 columns]

# %%
#Group by streaming platform on Rating and find the average.
movies_df_groupby=clean_movies_df.groupby(["Streaming platform"])
average_rating=movies_df_groupby.mean("Rating").drop(columns=['Year'])
average_rating.sort_values(by=["Rating"],ascending=False)
# Out:
#                        Rating
# Streaming platform
# Hulu                60.262990
# Disney+             58.312364
# Netflix             54.179509
# Prime Video         50.379512

# %% [markdown]
# The streaming paltform that has the highest average rating for movies is Hulu.

# %%
#group by mean to see which platform offers the most recent movies based on average
recent_movies=movies_df_groupby.mean()
recent_movies
# Out:
#                            Year     Rating
# Streaming platform
# Disney+             1997.033623  58.312364
# Hulu                2012.236479  60.262990
# Netflix             2014.950704  54.179509
# Prime Video         2002.132927  50.379512

# %% [markdown]
# On average we can see that Hulu offers more recent movies than any other platform.

# %% [markdown]
# #### Which platform offers movies for a specific age group?

# %%
#split age to convert it to float
age_split=clean_movies_df['Age'].str.split('+', expand=True)
age_split
# Out:
#         0    1
# ID
# 1      18
# 2       7
# 3       7
# 4       7
# 5      18
# ...   ...  ...
# 9511  NaN  NaN
# 9512  NaN  NaN
# 9513  NaN  NaN
# 9514  NaN  NaN
# 9515    7
#
# [9515 rows x 2 columns]

# %%
#drop nan values since they are empty values
clean_movies_df['Age']=age_split[0]
drop_nan= clean_movies_df.dropna(subset=['Age'])
drop_nan.loc[drop_nan['Age']=='all','Age']=0
drop_nan['Age']=pd.to_numeric(drop_nan['Age'])
drop_nan
# Out:
# <ipython-input-196-1e1cc336c824>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_nan['Age']=pd.to_numeric(drop_nan['Age'])
#                                          Title  Year  Age Streaming platform  \
# ID
# 1                                 The Irishman  2019   18            Netflix
# 2                                       Dangal  2016    7            Netflix
# 3     David Attenborough: A Life on Our Planet  2020    7            Netflix
# 4            Lagaan: Once Upon a Time in India  2001    7            Netflix
# 5                                         Roma  2018   18            Netflix
# ...                                        ...   ...  ...                ...
# 9504      Disney My Music Story: Sukima Switch  2021   16            Disney+
# 9506                     Great Shark Chow Down  2019    7            Disney+
# 9508                         Texas Storm Squad  2020   13            Disney+
# 9509                           What the Shark?  2020   13            Disney+
# 9515       Women of Impact: Changing the World  2019    7            Disney+
#
#       Rating
# ID
# 1       98.0
# 2       97.0
# 3       95.0
# 4       94.0
# 5       94.0
# ...      ...
# 9504    16.0
# 9506    14.0
# 9508    14.0
# 9509    14.0
# 9515    10.0
#
# [5338 rows x 5 columns]

# %%
#Group the dataframe by age and streaming platform to review the difference

Age_groupby=drop_nan.groupby(["Age","Streaming platform"])
age_count=Age_groupby.count()
age_streaming=age_count.pivot_table(values='Title', index='Age', columns='Streaming platform')
age_streaming.reset_index(inplace=True)
age_streaming.columns.name=None
age_streaming
# Out:
#    Age  Disney+  Hulu  Netflix  Prime Video
# 0    0      370    33      139          156
# 1    7      278    88      304          420
# 2   13       70   161      372          395
# 3   16        4    26      149           97
# 4   18        3   342      842         1089

# %%
#define a function to plot the graph
def age_plot(df,name,color):
    plt.plot(df['Age'], df[name],
            c=color, 
             marker="o",
            alpha=0.8, label=name)

# %%
#plot graph for each streaming platform based on Age
fig= plt.figure(figsize=(8,5))
age_plot(age_streaming, 'Disney+', 'C0')
age_plot(age_streaming, 'Netflix', 'C1')
age_plot(age_streaming, 'Hulu', 'C5')
age_plot(age_streaming, 'Prime Video', 'C2')

#Add legend
lgnd = plt.legend(fontsize="medium", 
                  loc="best", title="Streaming platforms",
                  labelspacing=1)

#Add axis labels
plt.xticks(age_streaming['Age'].values)
plt.xlabel('Age')
plt.ylabel('Number of Movies')
plt.title('Summary of Age Restriction on Streaming Platforms')
plt.show()

# %% [markdown]
# From the graph we can see that Disney caters more to younger people below the age of 7 as compared to the others while Netflix and Prime Video cater significantly to people above the age of 18.
